# %%
from preprocess_llama3_enhanced_dataset import preprocess_dataset

preprocess_dataset(
    jsonl_path="../data/facecaption_data/metadata_cleaned.jsonl",
    image_dir="../data/facecaption_data/images",
    output_jsonl="../data/facecaption_data/metadata_llama3.jsonl",
    max_samples=5000,
    num_workers=10,
    model="llama3"
)
# Out:
# 🔁 Resuming — 0 already processed.
# 🚀 Enhancing 5000 new captions...
# Enhancing:  48%|███████████████████████████████████▍                                      | 4781/10000 [11:40:02<13:05:16,  9.03s/it]
